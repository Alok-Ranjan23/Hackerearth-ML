# %%
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd
import seaborn as sns

# %% [markdown]
# ## Read Dataset

# %%
train_data = pd.read_csv('Dataset/train.csv')

# %%
train_data.head()
# Out:
#    Allied_Nations  Diplomatic_Meetings_Set  Percent_Of_Forces_Mobilized  \
# 0              16                        1                         0.67
# 1               8                        1                         0.11
# 2               9                        1                         0.49
# 3               7                        0                         0.30
# 4               8                        1                         0.12
#
#    Hostile_Nations  Active_Threats  Inactive_Threats  Citizen_Fear_Index  \
# 0                3             6.0              25.0            0.787812
# 1                2            38.0              48.0            0.419236
# 2                3            32.0              69.0            0.582232
# 3                2            31.0              52.0            0.589574
# 4                5            13.0              42.0            0.552863
#
#    Closest_Threat_Distance(km)  Aircraft_Carriers_Responding  \
# 0                       324.36                             1
# 1                       359.34                             0
# 2                       332.84                             1
# 3                       358.28                             1
# 4                       364.64                             0
#
#    Troops_Mobilized(thousands)  DEFCON_Level     ID
# 0                     862400.0             3   7570
# 1                     959200.0             4  12128
# 2                     836000.0             3   2181
# 3                     924000.0             3   5946
# 4                     968000.0             2   9054

# %%
train_data.shape
# Out:
# (10000, 12)

# %%
train_data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 10000 entries, 0 to 9999
# Data columns (total 12 columns):
# Allied_Nations                  10000 non-null int64
# Diplomatic_Meetings_Set         10000 non-null int64
# Percent_Of_Forces_Mobilized     10000 non-null float64
# Hostile_Nations                 10000 non-null int64
# Active_Threats                  10000 non-null float64
# Inactive_Threats                10000 non-null float64
# Citizen_Fear_Index              10000 non-null float64
# Closest_Threat_Distance(km)     10000 non-null float64
# Aircraft_Carriers_Responding    10000 non-null int64
# Troops_Mobilized(thousands)     10000 non-null float64
# DEFCON_Level                    10000 non-null int64
# ID                              10000 non-null int64
# dtypes: float64(6), int64(6)
# memory usage: 937.6 KB

# %%
train_data.describe().T
# Out:
#                                 count           mean           std        min  \
# Allied_Nations                10000.0       8.317800      1.748802       5.00
# Diplomatic_Meetings_Set       10000.0       0.524100      0.500244       0.00
# Percent_Of_Forces_Mobilized   10000.0       0.270548      0.196434       0.00
# Hostile_Nations               10000.0       2.502300      1.311780       1.00
# Active_Threats                10000.0      15.754300     10.388906       1.00
# Inactive_Threats              10000.0      46.534600     34.012649       6.00
# Citizen_Fear_Index            10000.0       0.486639      0.134552       0.00
# Closest_Threat_Distance(km)   10000.0     350.885758     16.285744     290.44
# Aircraft_Carriers_Responding  10000.0       0.891300      0.329082       0.00
# Troops_Mobilized(thousands)   10000.0  917487.413333  92717.640162  739200.00
# DEFCON_Level                  10000.0       2.616600      0.802788       1.00
# ID                            10000.0    6266.554200   3610.170288       2.00
#
#                                         25%            50%            75%  \
# Allied_Nations                     7.000000       8.000000       9.000000
# Diplomatic_Meetings_Set            0.000000       1.000000       1.000000
# Percent_Of_Forces_Mobilized        0.090000       0.260000       0.430000
# Hostile_Nations                    2.000000       2.000000       3.000000
# Active_Threats                     7.000000      13.000000      21.000000
# Inactive_Threats                  21.000000      37.000000      62.000000
# Citizen_Fear_Index                 0.406021       0.486784       0.567548
# Closest_Threat_Distance(km)      340.260000     350.860000     360.400000
# Aircraft_Carriers_Responding       1.000000       1.000000       1.000000
# Troops_Mobilized(thousands)   836000.000000  897600.000000  976800.000000
# DEFCON_Level                       2.000000       3.000000       3.000000
# ID                              3139.750000    6280.500000    9391.500000
#
#                                      max
# Allied_Nations                     16.00
# Diplomatic_Meetings_Set             2.00
# Percent_Of_Forces_Mobilized         1.00
# Hostile_Nations                    16.00
# Active_Threats                     72.00
# Inactive_Threats                  289.00
# Citizen_Fear_Index                  1.00
# Closest_Threat_Distance(km)       425.06
# Aircraft_Carriers_Responding        2.00
# Troops_Mobilized(thousands)   1311200.00
# DEFCON_Level                        5.00
# ID                              12500.00
